# %%
from C_setting import *

print("C / C++ Notebook 環境已載入。")
print("可以開始使用 %%c 與 %%cpp。")
# Out:
# C / C++ Notebook 環境已載入。
# 可以開始使用 %%c 與 %%cpp。

# %%
% cpp

# vector<int> a = {10, 20, 30, 40}
# vector<int> a{10, 20, 30, 40}

# %%
# vector<int> a(5); -> 0 0 0 0 0 => [0] * 5 (numpy, pytorch)
# vector<int> a(5, 10); -> 10 10 10 10 10

# %%
# array(unkown) -> (meory length) / (type length) -> 20 / 4 => 5

# vector<int> a = {10, 20, 30};
# cout << a.size();

# a.empty() -> a = {} => True /  a = {10, 20, 30} => False

# a.push_back() / a.pop_back()

# int i = 0 -> a.size() => data type: size_t -> size_t i = 0

# %%
# int main() {
#     vector<int> a = {10, 20, 30, 40, 50};
#     for (int x : a) {
#         cout << x << endl;
#     }
#     return 0;
# }

# %%
# a.front() / a.back()
